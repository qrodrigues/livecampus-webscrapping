# %% [markdown]
# # Nodebook CSV Manager

# %% [markdown]
# #### Installation des librairies

# %%
# !pip install pandas

# %% [markdown]
# #### Import des librairies

# %%
import pandas as pd
from webscrapper import ScrapEpisodes
scrapper = ScrapEpisodes("https://www.spin-off.fr/calendrier_des_series.html")
episodes = scrapper.getAllEpisodes()
# Out:
# c:\xampp\htdocs\livecampus-webscrapping\webscrapper.py:11: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 11 of the file c:\xampp\htdocs\livecampus-webscrapping\webscrapper.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   return BeautifulSoup(code_source, "html")

# %%
#Sortie : ('01-10-2023', 'Corée du Sud', 'tvN', 'Arthdal Chronicles', '08', '2', 'serie-8887-Arthdal-Chronicles.html')
# Voulu sujet : <nom_serie>;<numero_de_lepisode>;<numero_de_la_saison>;...;<url_episode>
# Voulu df {'col1': [1, 2], 'col2': [3, 4]}

# Le nom de la série
# Le numéro de l’épisode
# Le numéro de la saison
# La date de diffusion de l’épisode
# Le pays d’origine
# La chaîne qui diffuse la série
# L’url

data_to_df = {
    "nom_serie" : [],
    "numero_de_lepisode" : [],
    "numero_de_la_saison" : [],
    "date_diffusion_episode" : [],
    "pays_origine" : [],
    "chaine_diffusion" : [],
    "url" : []
}

for i in episodes :
    data_to_df.get("nom_serie").append(i[3])
    data_to_df.get("numero_de_lepisode").append(i[4])
    data_to_df.get("numero_de_la_saison").append(i[5])
    data_to_df.get("date_diffusion_episode").append(i[0])
    data_to_df.get("pays_origine").append(i[1])
    data_to_df.get("chaine_diffusion").append(i[2])
    data_to_df.get("url").append(i[6])

print(data_to_df)
# Out:
# {'nom_serie': ['Arthdal Chronicles', 'Behind Your Touch', "Bob's Burgers", 'Entre Tierras', 'Family Guy', 'Heartland (CA)', 'Krapopolis', 'Last Week Tonight With John Oliver', "Les Mystères de l'amour", 'SkyMed', 'The Simpsons', 'The Villains of Valley View', 'The Walking Dead: Daryl Dixon', 'When Calls the Heart', '5è Rang', '66-5', '66-5', 'Alertes', 'American Dad!', 'Demain nous appartient', 'Familie Bundschuh', 'Ici tout commence', 'Infiltré(e)', 'Infiltré(e)', 'Kamikaze (NOR)', 'Murdoch Mysteries', 'Narvalo', 'Narvalo', 'Pure Boxer', 'SOKO Potsdam', 'The Irrational', 'The Long Shadow', 'The Long Shadow', 'The Long Shadow', 'The Long Shadow', 'The Long Shadow', 'The Long Shadow', 'Un Si Grand Soleil', 'Ví?az', 'Ahsoka', 'Alexandra Ehle', 'À coeur battant', 'Club Soly', 'Demain nous appartient', 'Found', 'Ici tout commence', 'Only Murders in The Building', 'Un Si Grand Soleil', 'Aller simple', 'American Horror Story', 'Archer (2009)', 'Assisted Living', 'Assisted Living', 'Assiste
# ...

# %%
df = pd.DataFrame(data_to_df)
df.head(15)
df.to_csv("./data/files/episodes.csv",sep=';')
